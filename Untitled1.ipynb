# %%
import os
import sys
import urllib.request
import json
client_id = "JVXdhzIvAoLUry5zpBkW"
client_secret = "o533NVZ4aN"
strs=input("번역할 문장을 입력하세요 : ")
encText = urllib.parse.quote(strs)
data = "source=ko&target=en&text=" + encText
url = "https://openapi.naver.com/v1/language/translate"
#url ="https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
asd=""""""
if(rescode==200):
    response_body = response.read()
    asd+=response_body.decode('utf-8')
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
#print(asd)
d=json.loads(asd)
print("번역된 문장 : "+d['message']['result']['translatedText'])
# Out:
# 번역할 문장을 입력하세요 : 학교
# 번역된 문장 : school

# %%
def AND(w1,w2):
    w1*=0.5
    w2*=0.5
    if w1+w2>0.8:
        return 1
    else :
        return 0

# %%
def translate(strw):
    client_id = "JVXdhzIvAoLUry5zpBkW"
    client_secret = "o533NVZ4aN"
    strs=str(strw)
    encText = urllib.parse.quote(strs)
    data = "source=ko&target=en&text=" + encText
    url = "https://openapi.naver.com/v1/language/translate"
    #url ="https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    asd=""""""
    if(rescode==200):
        response_body = response.read()
        asd+=response_body.decode('utf-8')
        #print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
    #print(asd)
    d=json.loads(asd)
    print("번역된 문장 : "+d['message']['result']['translatedText'])
    return d['message']['result']['translatedText']

# %%
translate("학교")
# Out:
# 번역된 문장 : school
# 'school'

# %%
translate("각 층의 활성화값들이 0과 1에 치우쳐 분포되어 있군요")
# Out:
# 번역된 문장 : Active value of each floor are weighted toward 0 and 1 is distributed.
# 'Active value of each floor are weighted toward 0 and 1 is distributed.'

# %%
def transEnglish(strw):
    client_id = "JVXdhzIvAoLUry5zpBkW"
    client_secret = "o533NVZ4aN"
    strs=str(strw)
    encText = urllib.parse.quote(strs)
    data = "source=en&target=ko&text=" + encText
    url = "https://openapi.naver.com/v1/language/translate"
    #url ="https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    asd=""""""
    if(rescode==200):
        response_body = response.read()
        asd+=response_body.decode('utf-8')
        #print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
    #print(asd)
    d=json.loads(asd)
    print("번역된 문장 : "+d['message']['result']['translatedText'])
    return d['message']['result']['translatedText']

# %%
transEnglish("i want play game with my notebook")
# Out:
# 번역된 문장 : 나는 노트와 함께 게임하고 싶다.
# '나는 노트와 함께 게임하고 싶다.'

# %%
translate("악성코드에 감염될 위험이 높아집니다")
# Out:
# 번역된 문장 : Higher risk of being infected with malware.
# 'Higher risk of being infected with malware.'

# %%
AND(5,5)
# Out:
# 1

# %%
AND(0.8,0.2)
# Out:
# 0

# %%
AND(0.8,0.9)
# Out:
# 1

# %%
from IPython.display import Image
Image("C:\\Users\\haho6\\Desktop\\pic\\62620594_p0_master1200.jpg")

# %%
print("Lasplace's Desire")
# Out:
# Lasplace's Desire

# %%
Image("C:\\Users\\haho6\\Desktop\\pic\\9.jpg")

# %%
def OR(w1,w2):
    w1*=0.5
    w2*=0.5
    b=0
    if w1+w2+b >= 0.5:
        return 1
    else :
        return 0

# %%
OR(1,1)
# Out:
# 1

# %%
OR(0,1)
# Out:
# 1

# %%
OR(0,0)
# Out:
# 0

# %%
def NAND(w1,w2):
    w1*=(-0.5)
    w2*=(-0.5)
    if w1+w2 >= 0:
        return 1
    else :
        return 0

# %%
NAND(1,1)
# Out:
# 0

# %%
NAND(0,0)
# Out:
# 1

# %%
NAND(1,0)
# Out:
# 0

# %%
def XOR(w1,w2):
    s1=NAND(w1,w2)

# %%
XOR(1,0)
# Out:
# 0

# %%
XOR(1,1)
# Out:
# 0

# %%
XOR(0,0)
# Out:
# 0
