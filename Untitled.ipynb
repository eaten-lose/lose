# %%
import tensorflow as tf

# %%
tf.VERSION
# Out:
# '1.3.0'

# %%
import numpy

# %%
print("las")
# Out:
# las

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.arange(0,5,0.2)
y=np.sin(x)

plt.plot(x,y)
plt.show()

# %%
from matplotlib.image import imread
img=imread("C:\\Users\\haho6\\Desktop\\pic\\62620594_p0_master1200.jpg")
plt.imshow(img)
plt.show()

# %%
from IPython.display import Image
Image("C:\\Users\\haho6\\Desktop\\pic\\62620594_p0_master1200.jpg")

# %%
Image("C:\\Users\\haho6\\Desktop\\pic\\65596394_p0_master1200.jpg")

# %%
Image("C:\\Users\\haho6\\Desktop\\pic\\10.png")

# %%
def AND(w1,w2):
    w1*=0.5
    w2*=0.5
    if w1+w2>0.8:
        return 1
    else :
        return 0

# %%
AND(1,1)
AND(0,1)

# %%
AND(1,1)

# %%
import os
import sys
import urllib.request
import json
client_id = "JVXdhzIvAoLUry5zpBkW"
client_secret = "o533NVZ4aN"
strs=input("번역할 문장을 입력하세요 : ")
encText = urllib.parse.quote(strs)
data = "source=ko&target=en&text=" + encText
url = "https://openapi.naver.com/v1/language/translate"
#url ="https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
asd=""""""
if(rescode==200):
    response_body = response.read()
    asd+=response_body.decode('utf-8')
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
#print(asd)
d=json.loads(asd)
print("번역된 문장 : "+d['message']['result']['translatedText'])

# %%
def translate(strw):
    client_id = "JVXdhzIvAoLUry5zpBkW"
    client_secret = "o533NVZ4aN"
    strs=str(strw)
    encText = urllib.parse.quote(strs)
    data = "source=ko&target=en&text=" + encText
    url = "https://openapi.naver.com/v1/language/translate"
    #url ="https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    asd=""""""
    if(rescode==200):
        response_body = response.read()
        asd+=response_body.decode('utf-8')
        #print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
    #print(asd)
    d=json.loads(asd)
    print("번역된 문장 : "+d['message']['result']['translatedText'])
    return 0

# %%
translate("학교 가기 싫다~~~ 정말 가기 싫어. 짜증나여!")
